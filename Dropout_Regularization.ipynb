# %% [markdown]
# <a href="https://colab.research.google.com/github/subham129/Deep-learning/blob/main/Dropout_Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('sonar_dataset.csv',header=None)

# %%
df.sample(5)
# Out:
#         0       1       2       3       4       5       6       7       8   \
# 38  0.0123  0.0022  0.0196  0.0206  0.0180  0.0492  0.0033  0.0398  0.0791
# 30  0.0240  0.0218  0.0324  0.0569  0.0330  0.0513  0.0897  0.0713  0.0569
# 83  0.0217  0.0340  0.0392  0.0236  0.1081  0.1164  0.1398  0.1009  0.1147
# 55  0.0201  0.0116  0.0123  0.0245  0.0547  0.0208  0.0891  0.0836  0.1335
# 52  0.0087  0.0046  0.0081  0.0230  0.0586  0.0682  0.0993  0.0717  0.0576
#
#         9   ...      51      52      53      54      55      56      57  \
# 38  0.0475  ...  0.0125  0.0134  0.0026  0.0038  0.0018  0.0113  0.0058
# 30  0.0389  ...  0.0162  0.0146  0.0093  0.0112  0.0094  0.0054  0.0019
# 83  0.1777  ...  0.0031  0.0103  0.0078  0.0077  0.0094  0.0031  0.0030
# 55  0.1199  ...  0.0076  0.0045  0.0056  0.0075  0.0037  0.0045  0.0029
# 52  0.0818  ...  0.0052  0.0038  0.0079  0.0114  0.0050  0.0030  0.0064
#
#         58      59  60
# 38  0.0047  0.0071   R
# 30  0.0066  0.0023   R
# ...

# %%
x = df.drop(columns=[60])
y = df[60]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
x_train.head()
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 73   0.0139  0.0222  0.0089  0.0108  0.0215  0.0136  0.0659  0.0954  0.0786
# 166  0.0411  0.0277  0.0604  0.0525  0.0489  0.0385  0.0611  0.1117  0.1237
# 138  0.0731  0.1249  0.1665  0.1496  0.1443  0.2770  0.2555  0.1712  0.0466
# 199  0.0116  0.0744  0.0367  0.0225  0.0076  0.0545  0.1110  0.1069  0.1708
# 84   0.0378  0.0318  0.0423  0.0350  0.1787  0.1635  0.0887  0.0817  0.1779
#
#          9   ...      50      51      52      53      54      55      56  \
# 73   0.1015  ...  0.0024  0.0062  0.0072  0.0113  0.0012  0.0022  0.0025
# 166  0.2300  ...  0.0181  0.0217  0.0038  0.0019  0.0065  0.0132  0.0108
# 138  0.1114  ...  0.0361  0.0444  0.0230  0.0290  0.0141  0.0161  0.0177
# 199  0.2271  ...  0.0202  0.0141  0.0103  0.0100  0.0034  0.0026  0.0037
# 84   0.2053  ...  0.0093  0.0046  0.0044  0.0078  0.0102  0.0065  0.0061
#
#          57      58      59
# 73   0.0059  0.0039  0.0048
# ...

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model = keras.Sequential([
    keras.layers.Dense(60,input_dim=60,activation='relu'),
    keras.layers.Dense(30,activation='relu'),
    keras.layers.Dense(15,activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')
])

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

model.fit(x_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 1s 5ms/step - loss: 0.6957 - accuracy: 0.4819
# Epoch 2/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6788 - accuracy: 0.5482
# Epoch 3/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6740 - accuracy: 0.5482
# Epoch 4/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6655 - accuracy: 0.6024
# Epoch 5/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6584 - accuracy: 0.5843
# Epoch 6/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6481 - accuracy: 0.6084
# Epoch 7/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6385 - accuracy: 0.6145
# Epoch 8/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6283 - accuracy: 0.6386
# Epoch 9/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6155 - accuracy: 0.6928
# Epoch 10/100
# ...

# %%
model.evaluate(x_test,y_test)
# Out:
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5388 - accuracy: 0.7857
# [0.5388416051864624, 0.7857142686843872]

# %%
y_pred = model.predict(x_test).reshape(-1)
y_pred = np.round(y_pred)
# Out:
# 2/2 [==============================] - 0s 5ms/step

# %%
from sklearn.metrics import confusion_matrix , classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.85      0.79        20
#            1       0.84      0.73      0.78        22
#
#     accuracy                           0.79        42
#    macro avg       0.79      0.79      0.79        42
# weighted avg       0.79      0.79      0.79        42

# %%
modle2 = keras.Sequential([
    keras.layers.Dense(60,input_dim=60,activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(30,activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(15,activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1,activation='sigmoid')
])
modle2.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
modle2.fit(x_train,y_train,epochs=1000,batch_size=8)
# Out:
# Epoch 1/1000
# 21/21 [==============================] - 1s 2ms/step - loss: 0.7585 - accuracy: 0.4699
# Epoch 2/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7409 - accuracy: 0.5181
# Epoch 3/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7062 - accuracy: 0.5000
# Epoch 4/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7118 - accuracy: 0.5301
# Epoch 5/1000
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6902 - accuracy: 0.5663
# Epoch 6/1000
# 21/21 [==============================] - 0s 3ms/step - loss: 0.7140 - accuracy: 0.4699
# Epoch 7/1000
# 21/21 [==============================] - 0s 3ms/step - loss: 0.7044 - accuracy: 0.4578
# Epoch 8/1000
# 21/21 [==============================] - 0s 3ms/step - loss: 0.6738 - accuracy: 0.5482
# Epoch 9/1000
# 21/21 [==============================] - 0s 3ms/step - loss: 0.6610 - accuracy: 0.5964
# Epoch 10/1000
# ...

# %%
modle2.evaluate(x_test,y_test)
# Out:
# 2/2 [==============================] - 0s 13ms/step - loss: 5.4210 - accuracy: 0.7857
# [5.420992851257324, 0.7857142686843872]

# %%
y_pred2 = modle2.predict(x_test).reshape(-1)
y_pred2 = np.round(y_pred)
# Out:
# 2/2 [==============================] - 0s 8ms/step

# %%
print(classification_report(y_test,y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.85      0.79        20
#            1       0.84      0.73      0.78        22
#
#     accuracy                           0.79        42
#    macro avg       0.79      0.79      0.79        42
# weighted avg       0.79      0.79      0.79        42
